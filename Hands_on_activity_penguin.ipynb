# %%
import seaborn as sns
sns.load_dataset("penguins")
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the penguins dataset
penguins = sns.load_dataset("penguins")

# Create a plot for mean flipper length with 95% confidence intervals
plt.figure(figsize=(8, 6))
sns.pointplot(data=penguins, x="species", y="flipper_length_mm", ci=95, capsize=0.2)
plt.title("Mean Flipper Length by Species (95% CI)")
plt.xlabel("Species")
plt.ylabel("Mean Flipper Length (mm)")
plt.show()
# Out:
# <ipython-input-6-32de0900c986>:9: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   sns.pointplot(data=penguins, x="species", y="flipper_length_mm", ci=95, capsize=0.2)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

penguins = sns.load_dataset("penguins")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

penguins = sns.load_dataset("penguins")

print(penguins.head())
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(8, 5))
sns.pointplot(data=penguins, x="species", y="flipper_length_mm", ci=95, capsize=0.1, join=False)

plt.title("Mean Flipper Length by Species (95% CI)")
plt.xlabel("Species")
plt.ylabel("Mean Flipper Length (mm)")
plt.show()
# Out:
# <ipython-input-16-d3c2533dc880>:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   sns.pointplot(data=penguins, x="species", y="flipper_length_mm", ci=95, capsize=0.1, join=False)
# <ipython-input-16-d3c2533dc880>:3: UserWarning:
#
# The `join` parameter is deprecated and will be removed in v0.15.0. You can remove the line between points with `linestyle='none'`.
#
#   sns.pointplot(data=penguins, x="species", y="flipper_length_mm", ci=95, capsize=0.1, join=False)

# %%
sns.pointplot(penguins, x="species", y="flipper_length_mm", hue="sex", capsize=0.2, dodge=True, color="orange", join=False)
plt.title("Mean Flipper Lenght by Species")
plt.ylabel("Mean Flipper Length (mm)")
plt.show()
# Out:
# <ipython-input-22-790a79eb3129>:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:orange'` for the same effect.
#
#   sns.pointplot(penguins, x="species", y="flipper_length_mm", hue="sex", capsize=0.2, dodge=True, color="orange", join=False)
# <ipython-input-22-790a79eb3129>:1: UserWarning:
#
# The `join` parameter is deprecated and will be removed in v0.15.0. You can remove the line between points with `linestyle='none'`.
#
#   sns.pointplot(penguins, x="species", y="flipper_length_mm", hue="sex", capsize=0.2, dodge=True, color="orange", join=False)
